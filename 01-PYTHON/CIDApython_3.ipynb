# %% [markdown]
# int,floats,strings,list,sets,dictionary,tuple,lambda,user-defined

# %%
l=[1,2,3]

# %%
dir(l)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# An object is iterable/iterator...
## that we can loop over some object

# %%
t=(1,2,3)
type(t)
# Out:
# tuple

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t=(1,1,1,2,3)

# %%
t.count(1)
# Out:
# 3

# %%
x1,y1=(0,0)  # only specifying the value without meanings
x2,y2=(2,3)
p1=x1,y1
p2=x2,y2

# %%
# namedtuple... = data structure... consistency and integrity!
## Want to give meaning to the positions of the data points,
### we use named tuple
# namedtuple(Classname,iterables)

# %%
from collections import namedtuple

# %%
Name=namedtuple('Name','First_name Last_name')

# %%
Name.First_name='Alex'

# %%
Name.Last_name='Jhon'

# %%
Name.First_name
# Out:
# 'Alex'

# %%
Name.__doc__ = 'This is a brand new Class Name, which serves a purpose of storing first name and last name'

# %%
Name.__doc__
# Out:
# 'This is a brand new Class Name, which serves a purpose of storing first name and last name'

# %%
isinstance(Name,tuple)
# Out:
# False

# %%
l=[1,2,3]  # type command not always returns the true source of the object

# %%
isinstance(l, list)
# Out:
# True

# %%
# sequence which has __iter__ and __getitem__ methods decalred in there class
## I M ABLE TO ITERARE OVER some seq, is it mandatory the seq must be indexiable= NO
## Iterator just like iterable objects is having __iter__,__next__ but the object is required
### to be declared everytime when its being iterated over.

# %%
for i in {1:'x',2:'y'}:
    print(i)
# Out:
# 1
# 2

# %%
l=[1,2,3]

# %%
dir(l)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# iterable/iterator

# %%
l=[1,2,3]

# %%
l is iter(l)
# Out:
# False

# %%
s={1,2,3}

# %%
s is iter(s)
# Out:
# False

# %%
l1=[1,2,3]
l2=[4,5,6]
l2
# Out:
# [4, 5, 6]

# %%
z=zip(l1,l2)

# %%
tuple(z)
# Out:
# ((1, 4), (2, 5), (3, 6))

# %%
z is iter(z)
# Out:
# True

# %%
for i in z:
    print(i)

# %%
for i in z:
    print(i)

# %%
l=[1,2,3]

# %%
for i in l:
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in l:
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in l:
    print(i)
# Out:
# 1
# 2
# 3

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
l=[1,2,3]

# %%
my_list=iter(l)

# %%
type(my_list)
# Out:
# list_iterator

# %%
dir(my_list)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__length_hint__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
next(my_list)
# Out:
# 1

# %%
next(my_list)
# Out:
# 2

# %%
next(my_list)
# Out:
# 3

# %%
next(my_list)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 next(my_list)
#
# StopIteration:

# %%
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
# operators : arithematic operators
            # : logical operators

# %%
d=dict(x=100)

# %%
dir(d)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
# operators : arithematic operators  + - * **
            # : logical operators

# %%
hex(2)
# Out:
# '0x2'

# %%
bool(323213) # boolean of zero is false,Non-zero it is True
             # boolean of empty-seq is False, non-empty True
# Truthyness of an object, every data type is assocaited with its corresponding
## boolean value
# Out:
# True

# %%
bool('wejhff')
# Out:
# True

# %%
# and(mul) or(addition) not(conjugate) 
# 'is' identity operator
# 'in' membership
# 'all' 
# 'any'
# operators evaluate the boolean value, and based upon whether
# it returns True or false, it returns the expressions a/q.
'''
expression1 and/or expression2 

'''

# %%
'' and 0   # short-circuiting
# Out:
# ''

# %%
type(None)
# Out:
# NoneType

# %%
x=None
y=10

# %%
bool(None)
# Out:
# False

# %%
'No' or 10 or 0 or [] or ''
# Out:
# 'No'

# %%
not(0)
# Out:
# True

# %%
'hello' is 'hello'
# Out:
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# C:\Users\tause\AppData\Local\Temp\ipykernel_36692\4220432193.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   'hello' is 'hello'
# True

# %%
1 is 1
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\tause\AppData\Local\Temp\ipykernel_36692\1728060598.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   1 is 1
# True

# %%
1 is 0
# Out:
# False

# %%
1 == 0
# Out:
# False

# %%
a=10
b=0 or 1
a/b
# Out:
# 10.0

# %%
#
